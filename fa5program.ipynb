# %% [markdown]
# <a href="https://colab.research.google.com/github/Briiieeee-M8/fa5programactivity/blob/maiN/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item_amount = input("amount")
item_price = input("price")

def multiply(item_amount, item_price):
    total = int(item_amount) * int(item_price)
    print(total)

multiply(item_amount, item_price)
